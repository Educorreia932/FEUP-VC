# %% [markdown]
# # 10. Local features – blob detectors

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def show_image(image, title="", cmap=""):
    plt.figure()
    plt.title(title)
    plt.imshow(image, cmap="gray")
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### **a)** Use the **SIFT** blob detector to detect the keypoints in an image and show their position over the image

# %%
image = cv2.imread("Images/lizard.bmp")
gray= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Initiate SIFT detector
sift = cv2.SIFT_create()

# Find the keypoints
kp = sift.detect(gray, None)

# Draw the keypoints (with size and orientation)
sift_image = cv2.drawKeypoints(gray, kp, image, (-1, -1, -1), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

show_image(sift_image, title="SIFT")

# %% [markdown]
# ### **b)** Use the ORB blob detector to detect the keypoints in an image and show their position over the image.

# %%
# Initiate ORB detector
orb = cv2.ORB_create()

# Find the keypoints with ORB
kp = orb.detect(image, None)

# Compute the descriptors with ORB
kp, des = orb.compute(image, kp)

# Draw only keypoints location,not size and orientation
image_2 = cv2.drawKeypoints(image, kp, None, color=(0,255,0), flags=0)

show_image(image_2)
